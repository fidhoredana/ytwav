# %%
#@title Mount Google Drive

from google.colab import drive
drive.mount('/content/drive')

# %%
#@title Install Library for Youtube WAV Download
# !pip install yt_dlp
# !pip install ffmpeg
# Out:
# Collecting yt_dlp
#   Downloading yt_dlp-2023.7.6-py2.py3-none-any.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 32.2 MB/s eta 0:00:00
# Collecting mutagen (from yt_dlp)
#   Downloading mutagen-1.46.0-py3-none-any.whl (193 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 23.7 MB/s eta 0:00:00
# Collecting pycryptodomex (from yt_dlp)
#   Downloading pycryptodomex-3.18.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 79.3 MB/s eta 0:00:00
# Collecting websockets (from yt_dlp)
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 17.1 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from yt_dlp) (2023.7.22)
# Collecting brotli (from yt_dlp)
#   Downloading Brotli-1.0.9-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 84.6 MB/s eta 0:00:00
# Installing collected packages: brotli, websockets, pycryptodomex, mutagen, yt_dlp
# Successfully installed brotli-1.0.9 mutagen-1.46.0 pycryptodomex-3.18.0 websockets-11.0.3 yt_dlp-2023.7.6
# Collecting ffmpeg
#   Downloading ffmpeg-1.4.tar.gz (5.1 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: ffmpeg
#   Building wheel for ffmpeg (setup.py) ... done
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6082 sha256=cf1b17149c5336c71b70f883e11f28c2296bb7bf922527625147f4b190f848b5
#   Stored in directory: /root/.cache/pip/wheels/8e/7a/69/cd6aeb83b126a7f04cbe7c9d929028dc52a6e7d525ff56003a
# Successfully built ffmpeg
# Installing collected packages: ffmpeg
# Successfully installed ffmpeg-1.4

# %%
#@title Download Youtube to WAV
from __future__ import unicode_literals
import yt_dlp
import ffmpeg
import sys
import urllib.request, json

# retrieve video title using urllib.request
url = "https://www.youtube.com/watch?v=kKsoxOVXvxc" #@param {type:"string"}
with urllib.request.urlopen(f"https://www.youtube.com/oembed?url={url}&format=json") as response:
    data = json.load(response)
    judul = data['title']

ydl_opts = {
    'format': 'bestaudio/best',
    'postprocessors': [{
        'key': 'FFmpegExtractAudio',
        'preferredcodec': 'wav',
    }],
    "outtmpl": f'drive/MyDrive/Youtube-Music/{judul}',
}

def download_from_url(url, judul):
    ydl.download([url])

with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    download_from_url(url, judul)
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=kKsoxOVXvxc
# [youtube] kKsoxOVXvxc: Downloading webpage
# [youtube] kKsoxOVXvxc: Downloading android player API JSON
# [info] kKsoxOVXvxc: Downloading 1 format(s): 251
# [dashsegments] Total fragments: 2
# [download] Destination: drive/MyDrive/Youtube-Music/DJ LITTLE SWING V2 X DJ HOMAGE WOLFGANG REMIX BY RADIF WG MENGKANE
# [download] 100% of   11.57MiB in 00:00:00 at 17.30MiB/s
# [ExtractAudio] Destination: drive/MyDrive/Youtube-Music/DJ LITTLE SWING V2 X DJ HOMAGE WOLFGANG REMIX BY RADIF WG MENGKANE.wav
# Deleting original file drive/MyDrive/Youtube-Music/DJ LITTLE SWING V2 X DJ HOMAGE WOLFGANG REMIX BY RADIF WG MENGKANE (pass -k to keep)
